# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as data
import os, cv2, numpy as np

# %%
import os
import cv2
import numpy as np
import torch
import torch.utils.data as data

def dataloading(image_folder):
    image_path = os.path.join(os.getcwd(), image_folder)
    image_list = []
    label_list = []

    for path in os.listdir(image_path):  # 파일명 예: Train_aug_num_label.png
        # 흑백 이미지 로드 (H, W)
        img = cv2.imread(os.path.join(image_path, path), cv2.IMREAD_GRAYSCALE)

        # 이미지 크기 확인 후 32x32로 리사이징 (필요 시)
        img = cv2.resize(img, (32, 32)) if img.shape != (32, 32) else img

        # 채널 차원 추가 (1, 32, 32) → CNN 입력 형태 맞추기
        img = np.expand_dims(img, axis=0)  # (1, H, W)

        # 정규화 (0~1 범위)
        img = img.astype(np.float32) / 255.0  

        # 라벨 추출 (one-hot 대신 정수형으로 변경)
        class_num = int(path.split('_')[-1].split('.')[0])  # 파일명에서 클래스 인덱스 추출

        # 리스트에 추가
        image_list.append(img)
        label_list.append(class_num)

    # NumPy → PyTorch Tensor 변환
    image_tensor = torch.tensor(np.array(image_list), dtype=torch.float32)  # (B, 1, 32, 32)
    label_tensor = torch.tensor(np.array(label_list), dtype=torch.long)  # 정수형 라벨 (B,)

    # PyTorch Dataset & DataLoader 생성
    dataset = data.TensorDataset(image_tensor, label_tensor)
    dataloader = data.DataLoader(dataset, batch_size=4, shuffle=True, num_workers=0)  # num_workers 조정 가능

    return dataloader

# %%
from models.model1.model import Net
train_model = Net()
dataloader = dataloading('data/train_data')

# %%
import torch.nn as nn
import torch.optim as optim
import os

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(train_model.parameters(), lr=0.001)
train_model.train()

# Training parameters
num_epochs = 100
total_step = len(dataloader)

# 저장할 디렉토리 생성 (필요시)
save_dir = "models/model1"
os.makedirs(save_dir, exist_ok=True)

# Best model tracking
best_accuracy = 0.0  # 최고 성능 저장

# Train loop
for epoch in range(num_epochs):
    correct = 0  # Accuracy 계산을 위한 변수 초기화
    total = 0
    epoch_loss = 0  # Epoch별 Loss 저장

    for i, (images, labels) in enumerate(dataloader):
        images = images.float()  # 이미지 float32 변환
        labels = labels.long()   # 라벨을 long (int64) 타입으로 변환
        
        # Forward
        outputs = train_model(images)
        loss = criterion(outputs, labels)
        epoch_loss += loss.item()

        # Backward & Optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Accuracy 계산
        _, predicted = torch.max(outputs, 1)  # 예측값
        correct += (predicted == labels).sum().item()  # 맞춘 개수
        total += labels.size(0)  # 전체 개수
        
        # Loss 출력 (100 step마다)
        if (i+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_step}], Loss: {loss.item():.4f}")

    # Epoch 끝난 후 정확도 출력
    accuracy = 100 * correct / total
    avg_loss = epoch_loss / total_step
    print(f"Epoch [{epoch+1}/{num_epochs}] Finished - Accuracy: {accuracy:.2f}%, Avg Loss: {avg_loss:.4f}")

    # 🔹 Best Model 저장 (Accuracy 최고값 갱신 시)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model_path = os.path.join(save_dir, "best.pth")
        torch.save(train_model.state_dict(), best_model_path)
        print(f"✅ Best Model Saved! Accuracy: {best_accuracy:.2f}%")

    # 🔹 Last Model 저장 (항상 저장)
    last_model_path = os.path.join(save_dir, "last.pth")
    torch.save(train_model.state_dict(), last_model_path)

print("🎉 Training Finished!")
print(f"🔥 Best Model Accuracy: {best_accuracy:.2f}% (Saved as 'best.pth')")
print(f"📌 Last Model Saved as 'last.pth'")
# Out:
# Epoch [1/100], Step [100/128], Loss: 1.9512
# Epoch [1/100] Finished - Accuracy: 18.00%, Avg Loss: 2.1389
# ✅ Best Model Saved! Accuracy: 18.00%
# Epoch [2/100], Step [100/128], Loss: 1.8440
# Epoch [2/100] Finished - Accuracy: 33.27%, Avg Loss: 1.8455
# ✅ Best Model Saved! Accuracy: 33.27%
# Epoch [3/100], Step [100/128], Loss: 2.5936
# Epoch [3/100] Finished - Accuracy: 49.32%, Avg Loss: 1.5548
# ✅ Best Model Saved! Accuracy: 49.32%
# Epoch [4/100], Step [100/128], Loss: 0.8484
# Epoch [4/100] Finished - Accuracy: 58.32%, Avg Loss: 1.2192
# ✅ Best Model Saved! Accuracy: 58.32%
# Epoch [5/100], Step [100/128], Loss: 1.2679
# Epoch [5/100] Finished - Accuracy: 63.99%, Avg Loss: 1.0533
# ✅ Best Model Saved! Accuracy: 63.99%
# Epoch [6/100], Step [100/128], Loss: 0.2139
# Epoch [6/100] Finished - Accuracy: 68.69%, Avg Loss: 0.8881
# ✅ Best Model Saved! Accuracy: 68.69%
# Epoch [7/100], Step [100/128], Loss: 1.4842
# Epoch [7/100] Finished - Accuracy: 73.78%, Avg Loss: 0.8201
# ✅ Best Model Saved! Accuracy: 73.78%
# Epoch [8/100], Step [100/128], Loss: 0.6786
# Epoch [8/100] Finished - Accuracy: 76.13%, Avg Loss: 0.6658
# ✅ Best Model Saved! Accuracy: 76.13%
# Epoch [9/100], Step [100/128], Loss: 0.1731
# Epoch [9/100] Finished - Accuracy: 77.50%, Avg Loss: 0.6074
# ✅ Best Model Saved! Accuracy: 77.50%
# Epoch [10/100], Step [100/128], Loss: 0.1098
# Epoch [10/100] Finished - Accuracy: 77.89%, Avg Loss: 0.6155
# ✅ Best Model Saved! Accuracy: 77.89%
# Epoch [11/100], Step [100/128], Loss: 0.6796
# Epoch [11/100] Finished - Accuracy: 82.58%, Avg Loss: 0.5098
# ✅ Best Model Saved! Accuracy: 82.58%
# Epoch [12/100], Step [100/128], Loss: 0.8839
# Epoch [12/100] Finished - Accuracy: 80.04%, Avg Loss: 0.4869
# Epoch [13/100], Step [100/128], Loss: 0.1119
# Epoch [13/100] Finished - Accuracy: 82.78%, Avg Loss: 0.4671
# ✅ Best Model Saved! Accuracy: 82.78%
# Epoch [14/100], Step [100/128], Loss: 0.0532
# Epoch [14/100] Finished - Accuracy: 87.48%, Avg Loss: 0.3704
# ✅ Best Model Saved! Accuracy: 87.48%
# Epoch [15/100], Step [100/128], Loss: 0.7394
# Epoch [15/100] Finished - Accuracy: 86.30%, Avg Loss: 0.3940
# Epoch [16/100], Step [100/128], Loss: 0.0086
# Epoch [16/100] Finished - Accuracy: 85.71%, Avg Loss: 0.4150
# Epoch [17/100], Step [100/128], Loss: 1.5543
# Epoch [17/100] Finished - Accuracy: 88.85%, Avg Loss: 0.3281
# ✅ Best Model Saved! Accuracy: 88.85%
# Epoch [18/100], Step [100/128], Loss: 0.5676
# Epoch [18/100] Finished - Accuracy: 84.93%, Avg Loss: 0.4046
# Epoch [19/100], Step [100/128], Loss: 0.0574
# Epoch [19/100] Finished - Accuracy: 87.87%, Avg Loss: 0.3080
# Epoch [20/100], Step [100/128], Loss: 0.1465
# Epoch [20/100] Finished - Accuracy: 87.28%, Avg Loss: 0.3532
# Epoch [21/100], Step [100/128], Loss: 0.3276
# Epoch [21/100] Finished - Accuracy: 85.71%, Avg Loss: 0.3309
# Epoch [22/100], Step [100/128], Loss: 0.0068
# Epoch [22/100] Finished - Accuracy: 87.08%, Avg Loss: 0.3086
# Epoch [23/100], Step [100/128], Loss: 0.8605
# Epoch [23/100] Finished - Accuracy: 88.85%, Avg Loss: 0.2937
# Epoch [24/100], Step [100/128], Loss: 0.2729
# Epoch [24/100] Finished - Accuracy: 90.22%, Avg Loss: 0.2670
# ✅ Best Model Saved! Accuracy: 90.22%
# Epoch [25/100], Step [100/128], Loss: 0.5471
# Epoch [25/100] Finished - Accuracy: 88.85%, Avg Loss: 0.3172
# Epoch [26/100], Step [100/128], Loss: 1.0566
# Epoch [26/100] Finished - Accuracy: 90.41%, Avg Loss: 0.2450
# ✅ Best Model Saved! Accuracy: 90.41%
# Epoch [27/100], Step [100/128], Loss: 0.1171
# Epoch [27/100] Finished - Accuracy: 91.39%, Avg Loss: 0.2562
# ✅ Best Model Saved! Accuracy: 91.39%
# Epoch [28/100], Step [100/128], Loss: 0.5556
# Epoch [28/100] Finished - Accuracy: 91.98%, Avg Loss: 0.2338
# ✅ Best Model Saved! Accuracy: 91.98%
# Epoch [29/100], Step [100/128], Loss: 0.0017
# Epoch [29/100] Finished - Accuracy: 93.35%, Avg Loss: 0.2144
# ✅ Best Model Saved! Accuracy: 93.35%
# Epoch [30/100], Step [100/128], Loss: 0.0052
# Epoch [30/100] Finished - Accuracy: 90.80%, Avg Loss: 0.2880
# Epoch [31/100], Step [100/128], Loss: 0.3516
# Epoch [31/100] Finished - Accuracy: 91.00%, Avg Loss: 0.2471
# Epoch [32/100], Step [100/128], Loss: 0.0011
# Epoch [32/100] Finished - Accuracy: 91.98%, Avg Loss: 0.2479
# Epoch [33/100], Step [100/128], Loss: 0.1235
# Epoch [33/100] Finished - Accuracy: 91.00%, Avg Loss: 0.2566
# Epoch [34/100], Step [100/128], Loss: 0.0065
# Epoch [34/100] Finished - Accuracy: 94.32%, Avg Loss: 0.1576
# ✅ Best Model Saved! Accuracy: 94.32%
# Epoch [35/100], Step [100/128], Loss: 0.5365
# Epoch [35/100] Finished - Accuracy: 92.95%, Avg Loss: 0.1914
# Epoch [36/100], Step [100/128], Loss: 0.3247
# Epoch [36/100] Finished - Accuracy: 92.76%, Avg Loss: 0.2013
# Epoch [37/100], Step [100/128], Loss: 1.5514
# Epoch [37/100] Finished - Accuracy: 93.74%, Avg Loss: 0.1914
# Epoch [38/100], Step [100/128], Loss: 0.0045
# Epoch [38/100] Finished - Accuracy: 91.78%, Avg Loss: 0.2467
# Epoch [39/100], Step [100/128], Loss: 0.1073
# Epoch [39/100] Finished - Accuracy: 93.15%, Avg Loss: 0.1653
# Epoch [40/100], Step [100/128], Loss: 0.0163
# Epoch [40/100] Finished - Accuracy: 94.52%, Avg Loss: 0.1580
# ✅ Best Model Saved! Accuracy: 94.52%
# Epoch [41/100], Step [100/128], Loss: 0.0090
# Epoch [41/100] Finished - Accuracy: 92.37%, Avg Loss: 0.1929
# Epoch [42/100], Step [100/128], Loss: 0.0066
# Epoch [42/100] Finished - Accuracy: 92.95%, Avg Loss: 0.1743
# Epoch [43/100], Step [100/128], Loss: 0.2708
# Epoch [43/100] Finished - Accuracy: 92.37%, Avg Loss: 0.2192
# Epoch [44/100], Step [100/128], Loss: 0.0035
# Epoch [44/100] Finished - Accuracy: 93.93%, Avg Loss: 0.1839
# Epoch [45/100], Step [100/128], Loss: 0.0772
# Epoch [45/100] Finished - Accuracy: 94.13%, Avg Loss: 0.1350
# Epoch [46/100], Step [100/128], Loss: 0.0013
# Epoch [46/100] Finished - Accuracy: 91.59%, Avg Loss: 0.2232
# Epoch [47/100], Step [100/128], Loss: 0.3247
# Epoch [47/100] Finished - Accuracy: 92.95%, Avg Loss: 0.2218
# Epoch [48/100], Step [100/128], Loss: 0.0098
# Epoch [48/100] Finished - Accuracy: 94.13%, Avg Loss: 0.1617
# Epoch [49/100], Step [100/128], Loss: 0.2261
# Epoch [49/100] Finished - Accuracy: 92.17%, Avg Loss: 0.2154
# Epoch [50/100], Step [100/128], Loss: 1.3750
# Epoch [50/100] Finished - Accuracy: 91.98%, Avg Loss: 0.2207
# Epoch [51/100], Step [100/128], Loss: 0.0290
# Epoch [51/100] Finished - Accuracy: 93.15%, Avg Loss: 0.1641
# Epoch [52/100], Step [100/128], Loss: 0.0007
# Epoch [52/100] Finished - Accuracy: 95.50%, Avg Loss: 0.1328
# ✅ Best Model Saved! Accuracy: 95.50%
# Epoch [53/100], Step [100/128], Loss: 0.0490
# Epoch [53/100] Finished - Accuracy: 93.74%, Avg Loss: 0.1915
# Epoch [54/100], Step [100/128], Loss: 0.1301
# Epoch [54/100] Finished - Accuracy: 93.15%, Avg Loss: 0.1663
# Epoch [55/100], Step [100/128], Loss: 0.1906
# Epoch [55/100] Finished - Accuracy: 92.56%, Avg Loss: 0.1868
# Epoch [56/100], Step [100/128], Loss: 0.0008
# Epoch [56/100] Finished - Accuracy: 93.54%, Avg Loss: 0.1820
# Epoch [57/100], Step [100/128], Loss: 0.1469
# Epoch [57/100] Finished - Accuracy: 94.32%, Avg Loss: 0.1639
# Epoch [58/100], Step [100/128], Loss: 0.0649
# Epoch [58/100] Finished - Accuracy: 96.48%, Avg Loss: 0.1228
# ✅ Best Model Saved! Accuracy: 96.48%
# Epoch [59/100], Step [100/128], Loss: 0.2565
# Epoch [59/100] Finished - Accuracy: 95.50%, Avg Loss: 0.1260
# Epoch [60/100], Step [100/128], Loss: 0.0004
# Epoch [60/100] Finished - Accuracy: 94.32%, Avg Loss: 0.1412
# Epoch [61/100], Step [100/128], Loss: 0.0158
# Epoch [61/100] Finished - Accuracy: 95.11%, Avg Loss: 0.1313
# Epoch [62/100], Step [100/128], Loss: 0.2176
# Epoch [62/100] Finished - Accuracy: 91.39%, Avg Loss: 0.2203
# Epoch [63/100], Step [100/128], Loss: 0.3215
# Epoch [63/100] Finished - Accuracy: 94.13%, Avg Loss: 0.1627
# Epoch [64/100], Step [100/128], Loss: 0.0377
# Epoch [64/100] Finished - Accuracy: 95.30%, Avg Loss: 0.1165
# Epoch [65/100], Step [100/128], Loss: 0.4876
# Epoch [65/100] Finished - Accuracy: 91.39%, Avg Loss: 0.2127
# Epoch [66/100], Step [100/128], Loss: 0.0000
# Epoch [66/100] Finished - Accuracy: 93.54%, Avg Loss: 0.1828
# Epoch [67/100], Step [100/128], Loss: 0.0521
# Epoch [67/100] Finished - Accuracy: 94.72%, Avg Loss: 0.1332
# Epoch [68/100], Step [100/128], Loss: 0.0025
# Epoch [68/100] Finished - Accuracy: 94.52%, Avg Loss: 0.1455
# Epoch [69/100], Step [100/128], Loss: 0.0001
# Epoch [69/100] Finished - Accuracy: 96.87%, Avg Loss: 0.1338
# ✅ Best Model Saved! Accuracy: 96.87%
# Epoch [70/100], Step [100/128], Loss: 0.0014
# Epoch [70/100] Finished - Accuracy: 96.48%, Avg Loss: 0.1265
# Epoch [71/100], Step [100/128], Loss: 0.0174
# Epoch [71/100] Finished - Accuracy: 93.74%, Avg Loss: 0.1579
# Epoch [72/100], Step [100/128], Loss: 0.0018
# Epoch [72/100] Finished - Accuracy: 94.91%, Avg Loss: 0.1321
# Epoch [73/100], Step [100/128], Loss: 0.0063
# Epoch [73/100] Finished - Accuracy: 95.69%, Avg Loss: 0.1112
# Epoch [74/100], Step [100/128], Loss: 0.4294
# Epoch [74/100] Finished - Accuracy: 94.52%, Avg Loss: 0.1639
# Epoch [75/100], Step [100/128], Loss: 0.0425
# Epoch [75/100] Finished - Accuracy: 95.30%, Avg Loss: 0.1452
# Epoch [76/100], Step [100/128], Loss: 0.1661
# Epoch [76/100] Finished - Accuracy: 96.09%, Avg Loss: 0.1339
# Epoch [77/100], Step [100/128], Loss: 0.0014
# Epoch [77/100] Finished - Accuracy: 95.11%, Avg Loss: 0.1343
# Epoch [78/100], Step [100/128], Loss: 0.0047
# Epoch [78/100] Finished - Accuracy: 97.46%, Avg Loss: 0.0809
# ✅ Best Model Saved! Accuracy: 97.46%
# Epoch [79/100], Step [100/128], Loss: 0.0215
# Epoch [79/100] Finished - Accuracy: 95.89%, Avg Loss: 0.0987
# Epoch [80/100], Step [100/128], Loss: 0.2093
# Epoch [80/100] Finished - Accuracy: 95.89%, Avg Loss: 0.1162
# Epoch [81/100], Step [100/128], Loss: 0.0069
# Epoch [81/100] Finished - Accuracy: 93.93%, Avg Loss: 0.1786
# Epoch [82/100], Step [100/128], Loss: 0.0142
# Epoch [82/100] Finished - Accuracy: 94.91%, Avg Loss: 0.1549
# Epoch [83/100], Step [100/128], Loss: 0.3347
# Epoch [83/100] Finished - Accuracy: 94.91%, Avg Loss: 0.1553
# Epoch [84/100], Step [100/128], Loss: 0.0292
# Epoch [84/100] Finished - Accuracy: 95.69%, Avg Loss: 0.1046
# Epoch [85/100], Step [100/128], Loss: 0.0000
# Epoch [85/100] Finished - Accuracy: 95.69%, Avg Loss: 0.1315
# Epoch [86/100], Step [100/128], Loss: 0.0000
# Epoch [86/100] Finished - Accuracy: 95.30%, Avg Loss: 0.1230
# Epoch [87/100], Step [100/128], Loss: 0.0041
# Epoch [87/100] Finished - Accuracy: 96.28%, Avg Loss: 0.1122
# Epoch [88/100], Step [100/128], Loss: 0.0001
# Epoch [88/100] Finished - Accuracy: 94.13%, Avg Loss: 0.1207
# Epoch [89/100], Step [100/128], Loss: 0.0607
# Epoch [89/100] Finished - Accuracy: 96.28%, Avg Loss: 0.1324
# Epoch [90/100], Step [100/128], Loss: 0.0107
# Epoch [90/100] Finished - Accuracy: 96.48%, Avg Loss: 0.0865
# Epoch [91/100], Step [100/128], Loss: 0.0000
# Epoch [91/100] Finished - Accuracy: 95.50%, Avg Loss: 0.1296
# Epoch [92/100], Step [100/128], Loss: 0.0066
# Epoch [92/100] Finished - Accuracy: 96.28%, Avg Loss: 0.1157
# Epoch [93/100], Step [100/128], Loss: 0.0355
# Epoch [93/100] Finished - Accuracy: 96.87%, Avg Loss: 0.0790
# Epoch [94/100], Step [100/128], Loss: 0.0078
# Epoch [94/100] Finished - Accuracy: 96.28%, Avg Loss: 0.1133
# Epoch [95/100], Step [100/128], Loss: 0.0349
# Epoch [95/100] Finished - Accuracy: 96.87%, Avg Loss: 0.0964
# Epoch [96/100], Step [100/128], Loss: 0.0042
# Epoch [96/100] Finished - Accuracy: 94.72%, Avg Loss: 0.1523
# Epoch [97/100], Step [100/128], Loss: 0.5939
# Epoch [97/100] Finished - Accuracy: 96.28%, Avg Loss: 0.1062
# Epoch [98/100], Step [100/128], Loss: 0.0945
# Epoch [98/100] Finished - Accuracy: 94.91%, Avg Loss: 0.1121
# Epoch [99/100], Step [100/128], Loss: 0.0000
# Epoch [99/100] Finished - Accuracy: 96.87%, Avg Loss: 0.0937
# Epoch [100/100], Step [100/128], Loss: 0.1315
# Epoch [100/100] Finished - Accuracy: 96.09%, Avg Loss: 0.0866
# 🎉 Training Finished!
# 🔥 Best Model Accuracy: 97.46% (Saved as 'best.pth')
# 📌 Last Model Saved as 'last.pth'

# %%
def predict_total(data_folder,models,encoder:dict):
    # dict 형태: 'cricles': 0, 'triangles': 1, 'squares': 2
    images = []
    encoder = {v: k for k, v in encoder.items()} 
    for i in range(0,len(os.listdir(data_folder))):
        num = str(i).zfill(3)
        path = f'TEST_{num}_0.png'
        images.append(cv2.imread(os.path.join(data_folder, path), cv2.IMREAD_GRAYSCALE))
    predicted = []
    for i, image in enumerate(images):
        image = cv2.resize(image, (32, 32)) if image.shape != (32, 32) else image
        image = np.expand_dims(image, axis=0)
        image = torch.tensor(image, dtype=torch.float32) / 255.0
        image = image.unsqueeze(0)
        output = models(image)
        _, pred = torch.max(output, 1) # 예측값
        pred = encoder.get(int(pred))
        print(f"Image {i} Prediction: {pred}")
        predicted.append(pred)
    return predicted

# %%
import json
encoder = json.load(open('data/label_encode.json'))
model = Net()
model.load_state_dict(torch.load('models/model1/best.pth'))
model.eval()
data_folder = 'data/test'
predicted = predict_total(data_folder,model,encoder)
# Out:
# Image 0 Prediction: airplane
# Image 1 Prediction: emotion_face
# Image 2 Prediction: emotion_face
# Image 3 Prediction: police_car
# Image 4 Prediction: truck
# Image 5 Prediction: airplane
# Image 6 Prediction: emotion_face
# Image 7 Prediction: cat
# Image 8 Prediction: ball
# Image 9 Prediction: police_car
# Image 10 Prediction: ball
# Image 11 Prediction: apple
# Image 12 Prediction: truck
# Image 13 Prediction: ball
# Image 14 Prediction: truck
# Image 15 Prediction: ball
# Image 16 Prediction: airplane
# Image 17 Prediction: police_car
# Image 18 Prediction: cat
# Image 19 Prediction: emotion_face
# Image 20 Prediction: truck
# Image 21 Prediction: truck
# Image 22 Prediction: apple
# Image 23 Prediction: truck
# Image 24 Prediction: airplane
# Image 25 Prediction: emotion_face
# Image 26 Prediction: police_car
# Image 27 Prediction: bird
# Image 28 Prediction: emotion_face
# Image 29 Prediction: cat
# Image 30 Prediction: cat
# Image 31 Prediction: truck
# Image 32 Prediction: emotion_face
# Image 33 Prediction: apple
# Image 34 Prediction: airplane
# Image 35 Prediction: apple
# Image 36 Prediction: bird
# Image 37 Prediction: truck
# Image 38 Prediction: emotion_face
# Image 39 Prediction: police_car
# Image 40 Prediction: truck
# Image 41 Prediction: ball
# Image 42 Prediction: apple
# Image 43 Prediction: cat
# Image 44 Prediction: truck
# Image 45 Prediction: ball
# Image 46 Prediction: apple
# Image 47 Prediction: truck
# Image 48 Prediction: apple
# Image 49 Prediction: ball
# Image 50 Prediction: cat
# Image 51 Prediction: truck
# Image 52 Prediction: airplane
# Image 53 Prediction: ball
# Image 54 Prediction: apple
# Image 55 Prediction: police_car
# Image 56 Prediction: building
# Image 57 Prediction: police_car
# Image 58 Prediction: ball
# Image 59 Prediction: police_car
# Image 60 Prediction: police_car
# Image 61 Prediction: police_car
# Image 62 Prediction: truck
# Image 63 Prediction: ball
# Image 64 Prediction: apple
# Image 65 Prediction: apple
# Image 66 Prediction: truck
# Image 67 Prediction: cat
# Image 68 Prediction: cat
# Image 69 Prediction: emotion_face
# Image 70 Prediction: ball
# Image 71 Prediction: airplane
# Image 72 Prediction: ball
# Image 73 Prediction: emotion_face
# Image 74 Prediction: airplane
# Image 75 Prediction: police_car
# Image 76 Prediction: emotion_face
# Image 77 Prediction: truck
# Image 78 Prediction: airplane
# Image 79 Prediction: ball
# Image 80 Prediction: apple
# Image 81 Prediction: cat
# Image 82 Prediction: ball
# Image 83 Prediction: apple
# Image 84 Prediction: airplane
# Image 85 Prediction: truck
# Image 86 Prediction: emotion_face
# Image 87 Prediction: cat
# Image 88 Prediction: cat
# Image 89 Prediction: airplane
# Image 90 Prediction: airplane
# Image 91 Prediction: airplane
# Image 92 Prediction: emotion_face
# Image 93 Prediction: cat
# Image 94 Prediction: truck
# Image 95 Prediction: airplane
# Image 96 Prediction: emotion_face
# Image 97 Prediction: cat
# Image 98 Prediction: truck
# Image 99 Prediction: apple
# Image 100 Prediction: airplane
# Image 101 Prediction: airplane
# Image 102 Prediction: ball
# Image 103 Prediction: police_car
# Image 104 Prediction: apple
# Image 105 Prediction: cat
# Image 106 Prediction: emotion_face
# Image 107 Prediction: cat
# Image 108 Prediction: police_car
# Image 109 Prediction: police_car
# Image 110 Prediction: police_car
# Image 111 Prediction: truck
# Image 112 Prediction: truck
# Image 113 Prediction: bird
# Image 114 Prediction: airplane
# Image 115 Prediction: cat
# Image 116 Prediction: apple
# Image 117 Prediction: airplane
# Image 118 Prediction: cat
# Image 119 Prediction: emotion_face
# Image 120 Prediction: emotion_face
# Image 121 Prediction: police_car
# Image 122 Prediction: emotion_face
# Image 123 Prediction: police_car
# Image 124 Prediction: truck
# Image 125 Prediction: truck
# Image 126 Prediction: police_car
# Image 127 Prediction: cat
# Image 128 Prediction: airplane
# Image 129 Prediction: cat
# Image 130 Prediction: airplane
# Image 131 Prediction: apple
# Image 132 Prediction: truck
# Image 133 Prediction: ball
# Image 134 Prediction: police_car
# Image 135 Prediction: ball
# Image 136 Prediction: apple
# Image 137 Prediction: airplane
# Image 138 Prediction: cat
# Image 139 Prediction: airplane
# Image 140 Prediction: truck
# Image 141 Prediction: apple
# Image 142 Prediction: ball
# Image 143 Prediction: truck
# Image 144 Prediction: truck
# Image 145 Prediction: truck
# Image 146 Prediction: emotion_face
# Image 147 Prediction: truck
# Image 148 Prediction: cat
# Image 149 Prediction: apple
# Image 150 Prediction: apple
# Image 151 Prediction: police_car
# Image 152 Prediction: cat
# Image 153 Prediction: truck
# Image 154 Prediction: cat
# Image 155 Prediction: truck
# Image 156 Prediction: cat
# Image 157 Prediction: ball
# Image 158 Prediction: truck
# Image 159 Prediction: cat
# Image 160 Prediction: apple
# Image 161 Prediction: cat
# Image 162 Prediction: apple
# Image 163 Prediction: police_car
# Image 164 Prediction: truck
# Image 165 Prediction: emotion_face
# Image 166 Prediction: cat
# Image 167 Prediction: apple
# Image 168 Prediction: emotion_face
# Image 169 Prediction: truck
# Image 170 Prediction: truck
# Image 171 Prediction: apple
# Image 172 Prediction: truck
# Image 173 Prediction: emotion_face
# Image 174 Prediction: emotion_face
# Image 175 Prediction: ball
# Image 176 Prediction: truck
# Image 177 Prediction: apple
# Image 178 Prediction: emotion_face
# Image 179 Prediction: police_car
# Image 180 Prediction: airplane
# Image 181 Prediction: truck
# Image 182 Prediction: truck
# Image 183 Prediction: emotion_face
# Image 184 Prediction: apple
# Image 185 Prediction: ball
# Image 186 Prediction: emotion_face
# Image 187 Prediction: police_car
# Image 188 Prediction: apple
# Image 189 Prediction: police_car
# Image 190 Prediction: truck
# Image 191 Prediction: truck
# Image 192 Prediction: police_car
# Image 193 Prediction: police_car
# Image 194 Prediction: emotion_face
# Image 195 Prediction: cat
# Image 196 Prediction: police_car
# Image 197 Prediction: airplane
# Image 198 Prediction: truck
# Image 199 Prediction: truck
# Image 200 Prediction: airplane
# Image 201 Prediction: police_car
# Image 202 Prediction: bird
# Image 203 Prediction: bird
# Image 204 Prediction: ball
# Image 205 Prediction: truck
# Image 206 Prediction: truck
# Image 207 Prediction: police_car
# Image 208 Prediction: truck
# Image 209 Prediction: cat
# Image 210 Prediction: truck
# Image 211 Prediction: ball
# Image 212 Prediction: emotion_face
# Image 213 Prediction: ball
# Image 214 Prediction: apple
# Image 215 Prediction: police_car
# Image 216 Prediction: cat
# Image 217 Prediction: police_car
# Image 218 Prediction: police_car
# Image 219 Prediction: apple
# Image 220 Prediction: police_car
# Image 221 Prediction: emotion_face
# Image 222 Prediction: apple
# Image 223 Prediction: truck
# Image 224 Prediction: apple
# Image 225 Prediction: airplane
# Image 226 Prediction: ball
# Image 227 Prediction: police_car
# Image 228 Prediction: airplane
# Image 229 Prediction: police_car
# Image 230 Prediction: ball
# Image 231 Prediction: cat
# Image 232 Prediction: emotion_face
# Image 233 Prediction: ball
# Image 234 Prediction: truck
# Image 235 Prediction: ball
# Image 236 Prediction: airplane
# Image 237 Prediction: police_car
# Image 238 Prediction: ball
# Image 239 Prediction: airplane
# Image 240 Prediction: apple
# Image 241 Prediction: truck
# Image 242 Prediction: building
# Image 243 Prediction: ball
# Image 244 Prediction: truck
# Image 245 Prediction: police_car
# Image 246 Prediction: cat
# Image 247 Prediction: cat
# Image 248 Prediction: police_car
# Image 249 Prediction: truck

# %%
import pandas as pd
df = pd.read_csv('data/sample_submission.csv')
df['label'] = predicted
df.to_csv('submission.csv', index=False)

# %%
df
# Out:
#            ID         label
# 0    TEST_000      airplane
# 1    TEST_001  emotion_face
# 2    TEST_002  emotion_face
# 3    TEST_003    police_car
# 4    TEST_004         truck
# ..        ...           ...
# 245  TEST_245    police_car
# 246  TEST_246           cat
# 247  TEST_247           cat
# 248  TEST_248    police_car
# 249  TEST_249         truck
#
# [250 rows x 2 columns]
