# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.utils.data as data
import os, cv2, numpy as np
import random
random.seed(42)

# %%
import os
import cv2
import numpy as np
import torch
import torch.utils.data as data

def dataloading(image_folder):
    image_path = os.path.join(os.getcwd(), image_folder)
    image_list = []
    label_list = []

    for path in os.listdir(image_path):  # 파일명 예: Train_aug_num_label.png
        # 흑백 이미지 로드 (H, W)
        img = cv2.imread(os.path.join(image_path, path), cv2.IMREAD_GRAYSCALE)

        # 이미지 크기 확인 후 32x32로 리사이징 (필요 시)
        img = cv2.resize(img, (32, 32)) if img.shape != (32, 32) else img

        # 채널 차원 추가 (1, 32, 32) → CNN 입력 형태 맞추기
        img = np.expand_dims(img, axis=0)  # (1, H, W)

        # 정규화 (0~1 범위)
        img = img.astype(np.float32) / 255.0 if img.max() > 1 else img

        # 라벨 추출 (one-hot 대신 정수형으로 변경)
        class_num = int(path.split('_')[-1].split('.')[0])  # 파일명에서 클래스 인덱스 추출

        # 리스트에 추가
        image_list.append(img)
        label_list.append(class_num)

    # NumPy → PyTorch Tensor 변환
    image_tensor = torch.tensor(np.array(image_list), dtype=torch.float32)  # (B, 1, 32, 32)
    label_tensor = torch.tensor(np.array(label_list), dtype=torch.long)  # 정수형 라벨 (B,)

    # PyTorch Dataset & DataLoader 생성
    dataset = data.TensorDataset(image_tensor, label_tensor)
    return dataset

# %%
import torch.nn as nn
import torch.nn.init as init

def initialize_weights(model):
    """
    모델의 모든 레이어에 대해 가중치를 초기화하는 함수.
    """
    for m in model.modules():
        if isinstance(m, nn.Conv2d):
            init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                init.constant_(m.bias, 0)
        elif isinstance(m, nn.Linear):
            init.xavier_normal_(m.weight)
            init.constant_(m.bias, 0)
        elif isinstance(m, nn.BatchNorm2d):
            init.constant_(m.weight, 1)
            init.constant_(m.bias, 0)

# %%
dataset = dataloading('data/train_data')

# %%
epochs = 500
batch_size = 32
learning_rate = 0.01
early_stopping_patience = 50
early_stopping_counter = 0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import os
import matplotlib.pyplot as plt

# 🔹 데이터 로딩 (Train:Valid = 90:10 split)
train_dataset, valid_dataset = torch.utils.data.random_split(
    dataset, 
    [int(len(dataset) * 0.8), len(dataset) - int(len(dataset) * 0.8)], 
    generator=torch.Generator().manual_seed(42)
)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %%
# MixUp 및 CutMix 정의
from torchvision.transforms import v2
mixup = v2.MixUp(num_classes=10)
cutmix = v2.CutMix(num_classes=10)
mixup_cutmix = v2.RandomChoice([mixup, cutmix])

# %%
# 모델 초기화 
train_model = Net()
initialize_weights(train_model)
from models.model2.model import Net
train_model = Net()

# %%
# 🔹 GPU 사용 여부 확인
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🔥 Using device: {device}")

# 모델을 GPU로 이동
train_model.to(device)

# 🔹 손실 함수 & 옵티마이저 (Weight Decay 추가)
criterion = nn.CrossEntropyLoss()  # ✅ CrossEntropyLoss 사용
optimizer = optim.Adam(train_model.parameters(), lr=learning_rate, weight_decay=1e-5)

# 🔹 ReduceLROnPlateau 적용 (Validation 성능 안 좋아지면 lr 감소)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=5, factor=0.5)

# 🔹 Early Stopping 설정
best_valid_loss = float('inf')

# 🔹 History 저장용 리스트
train_loss_history = []
train_acc_history = []
valid_loss_history = []
valid_acc_history = []

# 🔹 Training Loop
for epoch in range(epochs):
    train_correct, train_total, train_loss = 0, 0, 0  
    train_model.train()

    for images, labels in train_loader:
        images, labels = mixup_cutmix(images, labels)  # ✅ MixUp & CutMix 적용
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = train_model(images)

        # ✅ CrossEntropyLoss는 soft label을 지원하므로 그대로 사용 가능
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)

        # ✅ `labels`가 2D(one-hot)라면 `argmax()` 적용, 아니면 그대로 사용
        if labels.dim() > 1:
            labels = labels.argmax(dim=1)

        train_correct += (predicted == labels).sum().item()
        train_total += labels.size(0)

    train_accuracy = 100 * train_correct / train_total
    avg_train_loss = train_loss / len(train_loader)

    # 🔹 Validation Step
    valid_correct, valid_total, valid_loss = 0, 0, 0
    train_model.eval()
    
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = train_model(images)
            loss = criterion(outputs, labels)  # ✅ CrossEntropyLoss 사용

            valid_loss += loss.item()

            _, predicted = torch.max(outputs, 1)

            # ✅ `labels`가 2D(one-hot)라면 `argmax()` 적용, 아니면 그대로 사용
            if labels.dim() > 1:
                labels = labels.argmax(dim=1)

            valid_correct += (predicted == labels).sum().item()
            valid_total += labels.size(0)

    valid_accuracy = 100 * valid_correct / valid_total
    avg_valid_loss = valid_loss / len(valid_loader)

    # 🔹 History 저장
    train_loss_history.append(avg_train_loss)
    train_acc_history.append(train_accuracy)
    valid_loss_history.append(avg_valid_loss)
    valid_acc_history.append(valid_accuracy)

    # 🔹 Early Stopping 체크
    if avg_valid_loss < best_valid_loss:
        best_valid_loss = avg_valid_loss
        early_stopping_counter = 0
        torch.save(train_model.state_dict(), "models/model2/best.pth")  # ✅ Best Model 저장
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= early_stopping_patience:
            print("❌ Early Stopping Activated!")
            break

    scheduler.step(avg_valid_loss)  # 🔹 Learning Rate 감소

    print(f"Epoch [{epoch+1}/{epochs}]")
    print(f"  ✅ Train - Accuracy: {train_accuracy:.2f}%, Avg Loss: {avg_train_loss:.4f}")
    print(f"  ✅ Valid - Accuracy: {valid_accuracy:.2f}%, Avg Loss: {avg_valid_loss:.4f}")

print("🎉 Training Finished!")

# %%
# 🔹 Loss & Accuracy 그래프 그리기
plt.figure(figsize=(12, 5))

# 🔹 Loss 그래프
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss_history) + 1), train_loss_history, label="Train Loss")
plt.plot(range(1, len(valid_loss_history) + 1), valid_loss_history, label="Valid Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training & Validation Loss")
plt.legend()

# 🔹 Accuracy 그래프
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc_history) + 1), train_acc_history, label="Train Accuracy")
plt.plot(range(1, len(valid_acc_history) + 1), valid_acc_history, label="Valid Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Training & Validation Accuracy")
plt.legend()

# 🔹 그래프 출력
plt.tight_layout()
plt.show()

# %%
def predict_total(data_folder,models,encoder:dict):
    # dict 형태: 'cricles': 0, 'triangles': 1, 'squares': 2
    images = []
    encoder = {v: k for k, v in encoder.items()} 
    for i in range(0,len(os.listdir(data_folder))):
        num = str(i).zfill(3)
        path = f'TEST_{num}_0.png'
        images.append(cv2.imread(os.path.join(data_folder, path), cv2.IMREAD_GRAYSCALE))
    predicted = []
    for i, image in enumerate(images):
        image = cv2.resize(image, (32, 32)) if image.shape != (32, 32) else image
        image = np.expand_dims(image, axis=0)
        image = torch.tensor(image, dtype=torch.float32) / 255.0
        image = image.unsqueeze(0)
        output = models(image)
        _, pred = torch.max(output, 1) # 예측값
        pred = encoder.get(int(pred))
        predicted.append(pred)
    return predicted

# %%
import json
encoder = json.load(open('data/label_encode.json'))
model = Net()
model.load_state_dict(torch.load('models/model2/best.pth'))
model.eval()
data_folder = 'data/test'
predicted = predict_total(data_folder,model,encoder)

# %%
import pandas as pd
df = pd.read_csv('data/sample_submission.csv')
df['label'] = predicted
df.to_csv('submission.csv', index=False)

# %%
answer = pd.read_csv('data/label.txt', delimiter=',')
answer['label'] = answer[' label'].str.strip()
answer = answer.drop(columns=[' label'])
acc = (df['label'] == answer['label']).sum() / len(df)
print(model)
print(f"Accuracy: {acc}")
print("Submission file saved as 'submission.csv'")

# %%
# Merge the dataframes on the 'ID' column
diff = (df['label'] != answer['label'])
comparison_df = pd.DataFrame({'ID': df['ID'], 'label_pred': df['label'], 'label_true': answer['label']})

# Find the rows where the predicted label does not match the true label
incorrect_predictions = comparison_df[comparison_df['label_pred'] != comparison_df['label_true']]

# Display the incorrect predictions
incorrect_predictions

# %%
# Load the test data for incorrect predictions
incorrect_images = []
data_folder = 'data/test'
for idx in incorrect_predictions['ID']:
    path = os.path.join(data_folder, f"{idx}_0.png")
    image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    image = cv2.resize(image, (32, 32)) if image.shape != (32, 32) else image
    image = np.expand_dims(image, axis=0)
    image = torch.tensor(image, dtype=torch.float32) / 255.0
    image = image.unsqueeze(0)
    incorrect_images.append(image)

# Stack the images into a single tensor

# %%
import matplotlib.pyplot as plt
import numpy as np

columns = 4
rows = (len(incorrect_images) + columns - 1) // columns
fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(15, 15), squeeze=False)

# Flatten axes to avoid indexing issues when there are fewer than 4 images
axes = np.array(axes).reshape(rows, columns)

for idx, image in enumerate(incorrect_images):
    ax = axes[idx // columns, idx % columns]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(f"ID: {incorrect_predictions.iloc[idx]['ID']}\n"
                 f"Pred: {incorrect_predictions.iloc[idx]['label_pred']}\n"
                 f"True: {incorrect_predictions.iloc[idx]['label_true']}")
    ax.axis('off')

# Hide unused subplots
for idx in range(len(incorrect_images), rows * columns):
    axes[idx // columns, idx % columns].axis('off')

plt.tight_layout()
plt.show()
